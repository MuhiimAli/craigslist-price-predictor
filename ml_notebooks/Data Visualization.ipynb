# %%
import json
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
with open("../data/item_with_images.json", "r") as items_json:
    items = json.load(items_json)

# %%
items_df = pd.DataFrame(items)

# %%
items_df.head()
# Out:
#                                         title             metadata  price  \
# 0  kitchenaid measuring cups & spoons plastic  7 mins ago·westerly    5.0
# 1    hoffritz measuring spoon stainless steel  7 mins ago·westerly    4.0
# 2           bell ballistic 5' 10mm cable lock  7 mins ago·westerly    7.0
# 3           craftsman 3/8" drive 3" extension  7 mins ago·westerly    3.0
# 4                            wall/shelf clock  7 mins ago·westerly    5.0
#
#                                                 link  \
# 0  https://providence.craigslist.org/hsh/d/wester...
# 1  https://providence.craigslist.org/hsh/d/wester...
# 2  https://providence.craigslist.org/bop/d/wester...
# 3  https://providence.craigslist.org/tls/d/wester...
# 4  https://providence.craigslist.org/hsh/d/wester...
#
#                                               images  num_images category  \
# 0  [https://images.craigslist.org/00C0C_eGe6uOxr3...           1      hsh
# 1  [https://images.craigslist.org/01010_kux8s1c6I...           1      hsh
# 2  [https://images.craigslist.org/01616_4XQPW7w2G...           1      bop
# 3  [https://images.craigslist.org/00707_8IKEqaDqP...           1      tls
# 4  [https://images.craigslist.org/01414_4fFEKGldF...           1      hsh
#
#    metadata_length  date  location  mileage
# 0                2  3/14  westerly      NaN
# 1                2  3/14  westerly      NaN
# 2                2  3/14  westerly      NaN
# 3                2  3/14  westerly      NaN
# 4                2  3/14  westerly      NaN

# %%
items_df = items_df[items_df["category"] != "for"]

# %%
cat_map = {
    "spo": "Sporting Goods",
    "clt": "Collectibles",
    "tls": "Tools",
    "fuo": "Furniture",
    "hsh": "Household",
    "pts": "Auto Parts",
    "grd": "Garden",
    "msg": "Music Instruments",
    "ctd": "Cars and Trucks",
    "clo": "Clothes and Accessories"
}
cat_map.values()
# Out:
# dict_values(['Sporting Goods', 'Collectibles', 'Tools', 'Furniture', 'Household', 'Auto Parts', 'Garden', 'Music Instruments', 'Cars and Trucks', 'Clothes and Accessories'])

# %%
plt.figure(figsize = (12, 10))
sns.countplot(data = items_df, x = "category", order = items_df['category'].value_counts().index[:10])
plt.title("10 Most Common Categories")
plt.xticks(ticks = [i for i in range(10)], labels = list(cat_map.values()), rotation = -45, ha='left')
plt.subplots_adjust(bottom=0.3)
plt.savefig("../analysis_deliverable/visualizations/common_categories.png")
pass

# %%
# items_df["category_name"] = items_df["category"].map(cat_map)
