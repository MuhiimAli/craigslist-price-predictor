# %%
import numpy as np
import pandas as pd
import json

# %%
with open("../data/item_with_images.json", "r") as items_json:
    items = json.load(items_json)

# %%
items[:10]
# Out:
# [{'title': 'kitchenaid measuring cups & spoons plastic',
#   'metadata': '7 mins ago·westerly',
#   'price': 5.0,
#   'link': 'https://providence.craigslist.org/hsh/d/westerly-kitchenaid-measuring-cups/7726876655.html',
#   'images': ['https://images.craigslist.org/00C0C_eGe6uOxr3zC_07K0ak_300x300.jpg'],
#   'num_images': 1,
#   'category': 'hsh',
#   'metadata_length': 2,
#   'date': '3/14',
#   'location': 'westerly',
#   'mileage': None},
#  {'title': 'hoffritz measuring spoon stainless steel',
#   'metadata': '7 mins ago·westerly',
#   'price': 4.0,
#   'link': 'https://providence.craigslist.org/hsh/d/westerly-hoffritz-measuring-spoon/7717240495.html',
#   'images': ['https://images.craigslist.org/01010_kux8s1c6Il4_0jm0pO_300x300.jpg'],
#   'num_images': 1,
#   'category': 'hsh',
#   'metadata_length': 2,
#   'date': '3/14',
#   'location': 'westerly',
#   'mileage': None},
#  {'title': "bell ballistic 5' 10mm cable lock",
#   'metadata': '7 mins ago·westerly',
#   'price': 7.0,
#   'link': 'https://providence.craigslist.org/bop/d/westerly-bell-ballistic-10mm-cable-lock/7717240666.html',
#   'images': ['https://images.craigslist.org/01616_4XQPW7w2GhA_0CI0lM_300x300.jpg'],
#   'num_images': 1,
#   'category': 'bop',
#   'metadata_length': 2,
#   'date': '3/14',
#   'location': 'westerly',
#   'mileage': None},
#  {'title': 'craftsman 3/8" drive 3" extension',
#   'metadata': '7 mins ago·westerly',
#   'price': 3.0,
#   'link': 'https://providence.craigslist.org/tls/d/westerly-craftsman-8-drive-extension/7726876517.html',
#   'images': ['https://images.craigslist.org/00707_8IKEqaDqP7Y_07K0ak_300x300.jpg'],
#   'num_images': 1,
#   'category': 'tls',
#   'metadata_length': 2,
#   'date': '3/14',
#   'location': 'westerly',
#   'mileage': None},
#  {'title': 'wall/shelf clock',
#   'metadata': '7 mins ago·westerly',
#   'price': 5.0,
#   'link': 'https://providence.craigslist.org/hsh/d/westerly-wall-shelf-clock/7717243031.html',
#   'images': ['https://images.craigslist.org/01414_4fFEKGldFDF_0jm0pO_300x300.jpg'],
#   'num_images': 1,
#   'category': 'hsh',
#   'metadata_length': 2,
#   'date': '3/14',
#   'location': 'westerly',
#   'mileage': None},
#  {'title': 'calphalon commercial 2 burner griddle',
#   'metadata': '7 mins ago·westerly',
#   'price': 40.0,
#   'link': 'https://providence.craigslist.org/hsh/d/westerly-calphalon-commercial-burner/7717243852.html',
#   'images': ['https://images.craigslist.org/00Z0Z_4c9EC5a2Kda_0pO0jm_300x300.jpg'],
#   'num_images': 1,
#   'category': 'hsh',
#   'metadata_length': 2,
#   'date': '3/14',
#   'location': 'westerly',
#   'mileage': None},
#  {'title': "starbuck's barista milk frothing cup",
#   'metadata': '7 mins ago·westerly',
#   'price': 6.0,
#   'link': 'https://providence.craigslist.org/hsh/d/westerly-starbucks-barista-milk/7726876423.html',
#   'images': ['https://images.craigslist.org/00808_4cF3cFEwOwg_0jm0pO_300x300.jpg'],
#   'num_images': 1,
#   'category': 'hsh',
#   'metadata_length': 2,
#   'date': '3/14',
#   'location': 'westerly',
#   'mileage': None},
#  {'title': 'calphalon commercial roasting pan w/rack',
#   'metadata': '8 mins ago·westerly',
#   'price': 40.0,
#   'link': 'https://providence.craigslist.org/hsh/d/westerly-calphalon-commercial-roasting/7717243982.html',
#   'images': ['https://images.craigslist.org/00C0C_7MbBlK4mZHy_0pO0jm_300x300.jpg'],
#   'num_images': 1,
#   'category': 'hsh',
#   'metadata_length': 2,
#   'date': '3/14',
#   'location': 'westerly',
#   'mileage': None},
#  {'title': '2010 corvette zr1 clutch assembly',
#   'metadata': '8 mins ago·westerly',
#   'price': 125.0,
#   'link': 'https://providence.craigslist.org/pts/d/westerly-2010-corvette-zr1-clutch/7717993456.html',
#   'images': ['https://images.craigslist.org/00F0F_7j9cAqxK6Gu_0pO0ew_300x300.jpg'],
#   'num_images': 1,
#   'category': 'pts',
#   'metadata_length': 2,
#   'date': '3/14',
#   'location': 'westerly',
#   'mileage': None},
#  {'title': 'stainless steel kitchen wisk 12"',
#   'metadata': '8 mins ago·westerly',
#   'price': 3.0,
#   'link': 'https://providence.craigslist.org/hsh/d/westerly-stainless-steel-kitchen-wisk-12/7726876330.html',
#   'images': ['https://images.craigslist.org/00u0u_htsYEyiBVIR_0dG0if_300x300.jpg'],
#   'num_images': 1,
#   'category': 'hsh',
#   'metadata_length': 2,
#   'date': '3/14',
#   'location': 'westerly',
#   'mileage': None}]

# %%
with open("../data/text_embeds.npy", "rb") as npy_file:
    text_features = np.load(npy_file)

# %%
with open("../data/reduced_features.npy", "rb") as npy_file:
    image_features = np.load(npy_file)

# %%
image_features.shape
# Out:
# (3253, 210)

# %%
assert image_features.shape[0] == len(items)
assert text_features.shape[0] == len(items)

# %%
df = pd.DataFrame(items)[["num_images", "category", "date", "mileage", "price", "location"]]

# %%
df
# Out:
#       num_images category  date  mileage    price  \
# 0              1      hsh  3/14      NaN      5.0
# 1              1      hsh  3/14      NaN      4.0
# 2              1      bop  3/14      NaN      7.0
# 3              1      tls  3/14      NaN      3.0
# 4              1      hsh  3/14      NaN      5.0
# ...          ...      ...   ...      ...      ...
# 3248           1      atq  3/11      NaN    900.0
# 3249           2      fuo  3/11      NaN     30.0
# 3250           1      trb  3/11      NaN   6795.0
# 3251           1      fuo  3/11      NaN    300.0
# 3252           1      trb  3/11      NaN  10495.0
#
#                           location
# 0                         westerly
# 1                         westerly
# 2                         westerly
# 3                         westerly
# 4                         westerly
# ...                            ...
# 3248                       lincoln
# 3249                          pawt
# 3250  cm truck & trailer sales llc
# 3251                  saunderstown
# 3252  cm truck & trailer sales llc
#
# [3253 rows x 6 columns]

# %%
df["date"].unique()
# Out:
# array(['3/14', '3/13', '3/12', '3/16', '3/11'], dtype=object)

# %%
sum(df["mileage"].isna())
# Out:
# 3053

# %%
date2order = {
    "3/11": 0,
    "3/12": 1,
    "3/13": 2,
    "3/14": 3,
    "3/16": 5
}

# %%
df["date_idx"] = df["date"].map(date2order)

# %%
df = df.drop("date", axis = 1)

# %%
# Create dummy variables for both category and location
cat_dummy = pd.get_dummies(df["category"], prefix='category')
loc_dummy = pd.get_dummies(df["location"], prefix='location') #change#1: added location to the item attributes

# %%
df = pd.concat([df, cat_dummy, loc_dummy], axis=1)
df = df.drop(["category", "location"], axis=1)  # Remove original categorical columns

# %%
df = df.fillna(0.0)

# %%
df
# Out:
#       num_images  mileage    price  date_idx  category_app  category_art  \
# 0              1      0.0      5.0         3         False         False
# 1              1      0.0      4.0         3         False         False
# 2              1      0.0      7.0         3         False         False
# 3              1      0.0      3.0         3         False         False
# 4              1      0.0      5.0         3         False         False
# ...          ...      ...      ...       ...           ...           ...
# 3248           1      0.0    900.0         0         False         False
# 3249           2      0.0     30.0         0         False         False
# 3250           1      0.0   6795.0         0         False         False
# 3251           1      0.0    300.0         0         False         False
# 3252           1      0.0  10495.0         0         False         False
#
#       category_atq  category_avo  category_bab  category_bfd  ...  \
# 0            False         False         False         False  ...
# 1            False         False         False         False  ...
# 2            False         False         False         False  ...
# 3            False         False         False         False  ...
# 4            False         False         False         False  ...
# ...            ...           ...           ...           ...  ...
# 3248          True         False         False         False  ...
# 3249         False         False         False         False  ...
# 3250         False         False         False         False  ...
# 3251         False         False         False         False  ...
# 3252         False         False         False         False  ...
#
#       location_woonsocket  location_woonsocket ,r.i.  location_woonsocket ri  \
# 0                   False                      False                   False
# 1                   False                      False                   False
# 2                   False                      False                   False
# 3                   False                      False                   False
# 4                   False                      False                   False
# ...                   ...                        ...                     ...
# 3248                False                      False                   False
# 3249                False                      False                   False
# 3250                False                      False                   False
# 3251                False                      False                   False
# 3252                False                      False                   False
#
#       location_woonsocket, ri  location_ww/ coventry  location_ww/cov  \
# 0                       False                  False            False
# 1                       False                  False            False
# 2                       False                  False            False
# 3                       False                  False            False
# 4                       False                  False            False
# ...                       ...                    ...              ...
# 3248                    False                  False            False
# 3249                    False                  False            False
# 3250                    False                  False            False
# 3251                    False                  False            False
# 3252                    False                  False            False
#
#       location_ww/coventry  location_www.smdwoods.com  location_wyoming  \
# 0                    False                      False             False
# 1                    False                      False             False
# 2                    False                      False             False
# 3                    False                      False             False
# 4                    False                      False             False
# ...                    ...                        ...               ...
# 3248                 False                      False             False
# 3249                 False                      False             False
# 3250                 False                      False             False
# 3251                 False                      False             False
# 3252                 False                      False             False
#
#       location_🇺🇸#piano mover and tuning ..ri,ma.,ct, insured!
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3248                                              False
# 3249                                              False
# 3250                                              False
# 3251                                              False
# 3252                                              False
#
# [3253 rows x 355 columns]

# %%
df.to_csv("../data/items_processed.csv", index = False)
